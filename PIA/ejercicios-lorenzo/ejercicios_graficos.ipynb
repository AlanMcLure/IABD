# %%
import numpy as np
import matplotlib.pyplot as plt

# Función para obtener los datos
def get_datos():
    datos = np.array(
        [[  2.01666708 ,  56.18031474], [  4.79734083 ,  47.18848199], [  9.23784581 ,  57.68974048], [ 14.11529384 ,  43.70348368],
         [ 14.92688637 ,  59.10244323], [ 17.34408196 ,  65.96080804], [ 17.62435324 ,  45.74334603], [ 22.41875021 ,  13.575581  ],
         [ 25.3139145  ,  68.43756969], [ 34.85886672 , 147.15375307], [ 38.87476262 ,  25.39687009], [ 42.01380169 ,  74.39010069],
         [ 46.63551059 ,  98.93395801], [ 49.58578273 , 116.07013679], [ 50.18371003 , 138.55546747], [ 52.06630172 , 139.36601894],
         [ 54.68810274 , 150.09622546], [ 57.13046193 , 156.14375739], [ 66.35609935 , 119.75844452], [ 69.05499042 , 139.08155228],
         [ 69.51252436 , 128.72247348], [ 69.83788756 , 152.65110462], [ 79.76649746 , 148.23106977], [ 81.83730552 , 137.86314926],
         [ 87.09879038 , 217.28932067], [ 89.00469759 , 168.64994509], [ 93.17139213 , 163.10598352], [ 93.66070686 , 200.47638924],
         [ 94.1944751  , 150.44019156], [ 97.36920633 , 173.2055957 ]]
    )
    return datos

# Cargar datos
datos = get_datos()

# Separar las columnas de los datos en x (gastos en educación) y y (PIB)
x = datos[:, 0]
y = datos[:, 1]

# Crear la gráfica de dispersión
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color="dodgerblue")

# Añadir título y etiquetas a los ejes
plt.title("Gasto en educación de los países de la OCDE", fontsize=14)
plt.xlabel("Gastos en educación (Miles de millones)", fontsize=12)
plt.ylabel("PIB (Miles de millones)", fontsize=12)

# Añadir cuadrícula
plt.grid(True, linestyle='--', alpha=0.6)

# Mostrar la gráfica
plt.show()


# resultados = []

# for index, (capask activacion, epochs) in enumerate(redes_neuronales):

#     model,history,tiempo_entrenamiento=compile_fit(capas,x_entrenamiento,y_entrenamiento,epocs,activacion)
#     mse_entrenamiento,coeficiente_determinacion_entrenamiento=get_metricas_modelo(model,x_entrenamiento,y_entrenamiento)
#     mse_validacion,coeficiente_determinacion_validacion=get

#     resultado=[str(index+1),str(capas),epochs,activacion,mse_entrenamiento,coeficiente_determinacion_entrenamiento]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función para obtener los datos
def get_datos():
    datos = np.array(
        [[  2.01666708 ,  56.18031474], [  4.79734083 ,  47.18848199], [  9.23784581 ,  57.68974048], [ 14.11529384 ,  43.70348368],
         [ 14.92688637 ,  59.10244323], [ 17.34408196 ,  65.96080804], [ 17.62435324 ,  45.74334603], [ 22.41875021 ,  13.575581  ],
         [ 25.3139145  ,  68.43756969], [ 34.85886672 , 147.15375307], [ 38.87476262 ,  25.39687009], [ 42.01380169 ,  74.39010069],
         [ 46.63551059 ,  98.93395801], [ 49.58578273 , 116.07013679], [ 50.18371003 , 138.55546747], [ 52.06630172 , 139.36601894],
         [ 54.68810274 , 150.09622546], [ 57.13046193 , 156.14375739], [ 66.35609935 , 119.75844452], [ 69.05499042 , 139.08155228],
         [ 69.51252436 , 128.72247348], [ 69.83788756 , 152.65110462], [ 79.76649746 , 148.23106977], [ 81.83730552 , 137.86314926],
         [ 87.09879038 , 217.28932067], [ 89.00469759 , 168.64994509], [ 93.17139213 , 163.10598352], [ 93.66070686 , 200.47638924],
         [ 94.1944751  , 150.44019156], [ 97.36920633 , 173.2055957 ]]
    )
    return datos

# Cargar datos
datos = get_datos()
x = datos[:, 0]  # Gasto en educación
y = datos[:, 1]  # PIB real

# Parámetros de la ecuación de la recta
a = 1.6  # Pendiente
b = 30   # Intersección

# Calcular el PIB predicho
x_line = np.linspace(min(x), max(x), 100)  # Generar puntos para la línea
y_line = a * x_line + b  # PIB predicho

# Crear el gráfico
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color="dodgerblue", label="PIB Real")  # Puntos reales
plt.plot(x_line, y_line, color="red", label="PIB Predicho\na=1.6 y b=30")  # Recta

# Añadir título y etiquetas
plt.title("Gasto en educación de los países de la OCDE", fontsize=14)
plt.xlabel("Gastos en educación (Miles de millones)", fontsize=12)
plt.ylabel("PIB (Miles de millones)", fontsize=12)

# Añadir cuadrícula y leyenda
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Función para obtener los datos
def get_datos():
    datos = np.array(
        [[  2.01666708 ,  56.18031474], [  4.79734083 ,  47.18848199], [  9.23784581 ,  57.68974048], [ 14.11529384 ,  43.70348368],
         [ 14.92688637 ,  59.10244323], [ 17.34408196 ,  65.96080804], [ 17.62435324 ,  45.74334603], [ 22.41875021 ,  13.575581  ],
         [ 25.3139145  ,  68.43756969], [ 34.85886672 , 147.15375307], [ 38.87476262 ,  25.39687009], [ 42.01380169 ,  74.39010069],
         [ 46.63551059 ,  98.93395801], [ 49.58578273 , 116.07013679], [ 50.18371003 , 138.55546747], [ 52.06630172 , 139.36601894],
         [ 54.68810274 , 150.09622546], [ 57.13046193 , 156.14375739], [ 66.35609935 , 119.75844452], [ 69.05499042 , 139.08155228],
         [ 69.51252436 , 128.72247348], [ 69.83788756 , 152.65110462], [ 79.76649746 , 148.23106977], [ 81.83730552 , 137.86314926],
         [ 87.09879038 , 217.28932067], [ 89.00469759 , 168.64994509], [ 93.17139213 , 163.10598352], [ 93.66070686 , 200.47638924],
         [ 94.1944751  , 150.44019156], [ 97.36920633 , 173.2055957 ]]
    )
    return datos

# Cargar datos
datos = get_datos()
x = datos[:, 0]  # Gasto en educación
y = datos[:, 1]  # PIB real

# Línea del modelo matemático
a = 1.6
b = 30
y_pred_model = a * x + b

# Red neuronal
def compile_fit(x,y,epochs):
    np.random.seed(5)
    tf.random.set_seed(5)
    random.seed(5)  
     
    model=Sequential()
    model.add(Dense(1,input_dim=1))
    model.compile(loss='mean_squared_error')
     
    history=model.fit(x, y,verbose=False,epochs=epochs) 

    return model, history

model, history = compile_fit(x, y, epochs=500)

# Predicciones de la red neuronal
y_pred_nn = model.predict(x)

# Coeficientes aprendidos por la red neuronal
a_pred = model.layers[0].get_weights()[0][0, 0]
b_pred = model.layers[0].get_weights()[1][0]

# Crear figura y ejes
fig, ax = plt.subplots()

# Graficar los datos y las predicciones
ax.scatter(x, y, label='PIB Real')
ax.plot(x, y_pred_model, color='red', label=f'PIB Predicho\nModelo: a={a} y b={b}')
ax.plot(x, y_pred_nn, color='green', label=f'PIB Predicho Red Neuronal\na={a_pred:.2f} y b={b_pred:.2f}')

# Personalizar gráfico
ax.set_title('Gasto en educación de los países de la OCDE')
ax.set_xlabel('Gastos en educación (Miles de millones)')
ax.set_ylabel('PIB (Miles de millones)')
ax.legend()
ax.grid(True)

# Mostrar gráfico
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Función para obtener los datos
def get_datos():
    datos = np.array(
        [[  2.01666708 ,  56.18031474], [  4.79734083 ,  47.18848199], [  9.23784581 ,  57.68974048], [ 14.11529384 ,  43.70348368],
         [ 14.92688637 ,  59.10244323], [ 17.34408196 ,  65.96080804], [ 17.62435324 ,  45.74334603], [ 22.41875021 ,  13.575581  ],
         [ 25.3139145  ,  68.43756969], [ 34.85886672 , 147.15375307], [ 38.87476262 ,  25.39687009], [ 42.01380169 ,  74.39010069],
         [ 46.63551059 ,  98.93395801], [ 49.58578273 , 116.07013679], [ 50.18371003 , 138.55546747], [ 52.06630172 , 139.36601894],
         [ 54.68810274 , 150.09622546], [ 57.13046193 , 156.14375739], [ 66.35609935 , 119.75844452], [ 69.05499042 , 139.08155228],
         [ 69.51252436 , 128.72247348], [ 69.83788756 , 152.65110462], [ 79.76649746 , 148.23106977], [ 81.83730552 , 137.86314926],
         [ 87.09879038 , 217.28932067], [ 89.00469759 , 168.64994509], [ 93.17139213 , 163.10598352], [ 93.66070686 , 200.47638924],
         [ 94.1944751  , 150.44019156], [ 97.36920633 , 173.2055957 ]]
    )
    return datos

# Cargar datos
datos = get_datos()
x = datos[:, 0]  # Gasto en educación
y = datos[:, 1]  # PIB real

# Línea del modelo matemático
a = 1.6
b = 30
y_pred_model = a * x + b

# Red neuronal
def compile_fit(x,y,epochs):
    np.random.seed(5)
    tf.random.set_seed(5)
    random.seed(5)  
     
    model=Sequential()
    model.add(Dense(1,input_dim=1))
    model.compile(loss='mean_squared_error')
     
    history=model.fit(x, y,verbose=False,epochs=epochs) 

    return model, history

model, history = compile_fit(x, y, epochs=2000)

loss = history.history['loss']

print(loss)
# Graficar la evolución de la pérdida durante las épocas
fig_loss, ax_loss = plt.subplots()

# Obtener los valores de pérdida
loss_values = history.history['loss']

# Graficar la pérdida a lo largo de las épocas
ax_loss.plot(range(1, len(loss_values) + 1), loss_values, label='Pérdida', color='blue')

# Personalizar el gráfico de la pérdida
ax_loss.set_title('Evolución de la Pérdida durante las Épocas')
ax_loss.set_xlabel('Épocas')
ax_loss.set_ylabel('Pérdida')
ax_loss.legend()
ax_loss.grid(True)

# Mostrar gráfico de la pérdida
plt.show()
# Out:
# [6133.890625, 6106.52978515625, 6086.7490234375, 6070.2294921875, 6055.5947265625, 6042.20849609375, 6029.7158203125, 6017.8935546875, 6006.595703125, 5995.71728515625, 5985.18017578125, 5974.9287109375, 5964.9150390625, 5955.10498046875, 5945.46923828125, 5935.984375, 5926.62939453125, 5917.38916015625, 5908.25048828125, 5899.2001953125, 5890.22998046875, 5881.330078125, 5872.49267578125, 5863.71240234375, 5854.9833984375, 5846.2998046875, 5837.658203125, 5829.05517578125, 5820.48583984375, 5811.9482421875, 5803.43994140625, 5794.95947265625, 5786.50146484375, 5778.06884765625, 5769.6552734375, 5761.2626953125, 5752.8876953125, 5744.53076171875, 5736.189453125, 5727.86376953125, 5719.55224609375, 5711.2548828125, 5702.970703125, 5694.6982421875, 5686.4384765625, 5678.189453125, 5669.95263671875, 5661.72607421875, 5653.5087890625, 5645.302734375, 5637.10595703125, 5628.9189453125, 5620.740234375, 5612.5712890625, 5604.4111328125, 5596.25927734375, 5588.11669921875, 5579.98193359375, 5571.85498046875, 5563.7373046875, 5555.62744140625, 5547.52490234375, 5539.431640625, 5531.34521484375, 5523.2666015625, 5515.19580078125, 5507.13232421875, 5499.0771484375, 5491.029296875, 5482.9892578125, 5474.9560546875, 5466.93115234375, 5458.9130859375, 5450.90380859375, 5442.89990234375, 5434.90478515625, 5426.9169921875, 5418.93701171875, 5410.962890625, 5402.9970703125, 5395.03857421875, 5387.0869140625, 5379.14306640625, 5371.2060546875, 5363.27783203125, 5355.35400390625, 5347.43994140625, 5339.5322265625, 5331.63134765625, 5323.7392578125, 5315.85302734375, 5307.97509765625, 5300.10302734375, 5292.23974609375, 5284.38232421875, 5276.53271484375, 5268.69091796875, 5260.85595703125, 5253.02783203125, 5245.20751953125, 5237.39404296875, 5229.58837890625, 5221.7890625, 5213.9970703125, 5206.21240234375, 5198.43603515625, 5190.66552734375, 5182.9033203125, 5175.14794921875, 5167.39990234375, 5159.65771484375, 5151.92431640625, 5144.19775390625, 5136.47802734375, 5128.76708984375, 5121.06201171875, 5113.36474609375, 5105.673828125, 5097.9912109375, 5090.314453125, 5082.64599609375, 5074.984375, 5067.33056640625, 5059.68310546875, 5052.0439453125, 5044.4111328125, 5036.78564453125, 5029.16650390625, 5021.5556640625, 5013.9521484375, 5006.35595703125, 4998.7666015625, 4991.1845703125, 4983.60986328125, 4976.04150390625, 4968.48193359375, 4960.92919921875, 4953.38330078125, 4945.84423828125, 4938.31298828125, 4930.78857421875, 4923.271484375, 4915.7607421875, 4908.2587890625, 4900.76416015625, 4893.275390625, 4885.794921875, 4878.32080078125, 4870.853515625, 4863.39404296875, 4855.94287109375, 4848.498046875, 4841.060546875, 4833.63037109375, 4826.20654296875, 4818.79052734375, 4811.38232421875, 4803.97998046875, 4796.5859375, 4789.1982421875, 4781.81787109375, 4774.4453125, 4767.08056640625, 4759.72314453125, 4752.3720703125, 4745.0283203125, 4737.6923828125, 4730.3623046875, 4723.04052734375, 4715.7255859375, 4708.41748046875, 4701.1171875, 4693.8232421875, 4686.537109375, 4679.2578125, 4671.986328125, 4664.72314453125, 4657.46630859375, 4650.216796875, 4642.97412109375, 4635.73876953125, 4628.51025390625, 4621.2890625, 4614.07568359375, 4606.86865234375, 4599.66943359375, 4592.47705078125, 4585.29150390625, 4578.11376953125, 4570.94384765625, 4563.7802734375, 4556.62451171875, 4549.47607421875, 4542.333984375, 4535.2001953125, 4528.07275390625, 4520.95263671875, 4513.84033203125, 4506.734375, 4499.6357421875, 4492.544921875, 4485.46044921875, 4478.3837890625, 4471.314453125, 4464.2529296875, 4457.19775390625, 4450.150390625, 4443.10986328125, 4436.0771484375, 4429.05029296875, 4422.03173828125, 4415.02001953125, 4408.0146484375, 4401.01708984375, 4394.0263671875, 4387.04443359375, 4380.0693359375, 4373.10107421875, 4366.14013671875, 4359.18603515625, 4352.23974609375, 4345.30029296875, 4338.36767578125, 4331.44287109375, 4324.5244140625, 4317.61376953125, 4310.70947265625, 4303.81298828125, 4296.9248046875, 4290.04296875, 4283.1689453125, 427 ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Función para obtener los datos
def get_datos():
    datos = np.array(
        [[  2.01666708 ,  56.18031474], [  4.79734083 ,  47.18848199], [  9.23784581 ,  57.68974048], [ 14.11529384 ,  43.70348368],
         [ 14.92688637 ,  59.10244323], [ 17.34408196 ,  65.96080804], [ 17.62435324 ,  45.74334603], [ 22.41875021 ,  13.575581  ],
         [ 25.3139145  ,  68.43756969], [ 34.85886672 , 147.15375307], [ 38.87476262 ,  25.39687009], [ 42.01380169 ,  74.39010069],
         [ 46.63551059 ,  98.93395801], [ 49.58578273 , 116.07013679], [ 50.18371003 , 138.55546747], [ 52.06630172 , 139.36601894],
         [ 54.68810274 , 150.09622546], [ 57.13046193 , 156.14375739], [ 66.35609935 , 119.75844452], [ 69.05499042 , 139.08155228],
         [ 69.51252436 , 128.72247348], [ 69.83788756 , 152.65110462], [ 79.76649746 , 148.23106977], [ 81.83730552 , 137.86314926],
         [ 87.09879038 , 217.28932067], [ 89.00469759 , 168.64994509], [ 93.17139213 , 163.10598352], [ 93.66070686 , 200.47638924],
         [ 94.1944751  , 150.44019156], [ 97.36920633 , 173.2055957 ]]
    )
    return datos

# Cargar datos
datos = get_datos()
x = datos[:, 0]  # Gasto en educación
y = datos[:, 1]  # PIB real

# Línea del modelo matemático
a = 1.6
b = 30
y_pred_model = a * x + b

def compile_fit(x,y,epochs):
    np.random.seed(5)
    tf.random.set_seed(5)
    random.seed(5)  
     
    model=Sequential()
    model.add(Dense(1,activation="relu",input_dim=1))
    model.add(Dense(10,activation="relu"))
    model.add(Dense(100,activation="relu"))
    model.add(Dense(300,activation="relu"))
    model.add(Dense(600,activation="relu"))
    model.add(Dense(900,activation="relu"))
    model.add(Dense(1800,activation="relu"))
    model.add(Dense(900,activation="relu"))   
    model.add(Dense(600,activation="relu"))        
    model.add(Dense(300,activation="relu"))        
    model.add(Dense(200,activation="relu"))
    model.add(Dense(100,activation="relu"))                    
    model.add(Dense(10,activation="relu"))                        
    model.add(Dense(1,input_dim=1))                        
    model.compile(loss='mean_squared_error',optimizer="Adam")
     
     
    history=model.fit(x, y,verbose=False, epochs=epochs) 
 
    return model,history

model, history = compile_fit(x, y, epochs=10000)

# Predicciones de la red neuronal
y_pred_nn = model.predict(x)

# Coeficientes aprendidos por la red neuronal
a_pred = model.layers[0].get_weights()[0][0, 0]
b_pred = model.layers[0].get_weights()[1][0]

# Crear figura y ejes
fig, ax = plt.subplots()

# Graficar los datos y las predicciones
ax.scatter(x, y, label='PIB Real')
ax.plot(x, y_pred_model, color='red', label=f'PIB Predicho\nModelo: a={a} y b={b}')
ax.plot(x, y_pred_nn, color='green', label=f'PIB Predicho Red Neuronal\na={a_pred:.2f} y b={b_pred:.2f}')

# Personalizar gráfico
ax.set_title('Gasto en educación de los países de la OCDE')
ax.set_xlabel('Gastos en educación (Miles de millones)')
ax.set_ylabel('PIB (Miles de millones)')
ax.legend()
ax.grid(True)

# Mostrar gráfico
plt.show()

# Graficar la evolución de la pérdida durante las épocas
fig_loss, ax_loss = plt.subplots()

# Obtener los valores de pérdida
loss_values = history.history['loss']

# Graficar la pérdida a lo largo de las épocas
ax_loss.plot(range(1, len(loss_values) + 1), loss_values, label=f'Loss: {loss_values[-1]}', color='blue')

# Personalizar el gráfico de la pérdida
ax_loss.set_title('Evolución de la Pérdida durante las Épocas')
ax_loss.set_xlabel('Épocas')
ax_loss.set_ylabel('Pérdida')
ax_loss.legend()
ax_loss.grid(True)

# Mostrar gráfico de la pérdida
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
